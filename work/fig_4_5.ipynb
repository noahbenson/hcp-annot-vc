# %% [markdown]
# ### Configurations

# %%
# The cache directories:
cache_path       = '/data/crcns2021/hcpannot-cache'
image_cache_path = f'{cache_path}/annot-images'
v123_cache_path  = f'{cache_path}/annot-v123'
csulc_cache_path = f'{cache_path}/annot-csulc'
results_path = '/data/crcns2021/results'
data_path = f'{results_path}/data_branch/save'
proc_path = f'{results_path}/proc'
traces_path = f'{proc_path}/traces'
paths_path = f'{proc_path}/paths'
labels_path = f'{proc_path}/labels'

#If you aren't using /data
import os
os.environ['HCPANNOT_LOAD_PATH'] = cache_path

# %% [markdown]
# ### Dependencies

# %%
import os
import hcpannot
import numpy as np
import pandas as pd
import neuropythy as ny
import matplotlib as mpl
import matplotlib.pyplot as plt
from collections import defaultdict
import matplotlib.font_manager as fm

from hcpannot.config import (
    subject_list,
    ventral_raters,
)
from hcpannot.proc import proc

# %%
# %matplotlib inline
fm.fontManager.addfont("HelveticaNeue-Light-08.ttf")

names = sorted({f.name for f in fm.fontManager.ttflist if "Helvetica" in f.name})
print(names)
# Out:
# ['Helvetica Neue', 'HelveticaNeue']

# %%
# Additional matplotlib preferences:
font_data = {'family':'sans-serif',
             'sans-serif':['Helvetica Neue'],
             'size': 10}
mpl.rc('font',**font_data)
# we want relatively high-res images, especially when saving to disk.
params = {
    'figure.dpi': 72*4,
    'savefig.dpi': 72*4,
    'legend.fontsize': 10,
    'axes.labelsize': 10,
    'axes.titlesize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10
}
mpl.rcParams.update(params)

# %%
# define constants
sub_contours = ['hV4_outer','hV4_VO1','VO1_VO2','VO_outer']
sids = subject_list.copy()

# %% [markdown]
# ### Create Fsaverage Dataframe

# %% [markdown]
# #### Sampling data points from the cache files

# %%
# use a random subject drawn by a random rater as an example before running all subjects
hemi = 'lh'
r = ventral_raters[1]
roi = sub_contours[1]
subject_id = sids[140]

path = os.path.join(proc_path, 'fsaverage', f"cacherater_{r}_{subject_id}_{hemi}_{roi}.mgz")
data = ny.load(path)

# %%
# the cache file includes x and y coordinates of 500 evenly spaced points along the contour
# to compute a linear mixed-effects model, we can use a subset of these points
# here we use every 10th point (50 points total)
sample_idx = np.arange(0, 500, 10)
data_x = data[0][sample_idx]
data_y = data[1][sample_idx]

# plot the contour using the subset of points
plt.plot(data_x, data_y)
plt.title(f'{subject_id} {hemi} {roi} {r}')
# Out:
# Text(0.5, 1.0, '680957 lh hV4_VO1 R2')

# %%
# sample the data points from the cache files for all subjects and raters
# and save them in a dataframe
# the dataframe has the following columns:
# value, coord, num_point, subject_id, hemi, roi, rater
data = []
sample_idx = np.arange(0, 500, 10)
missing = defaultdict(list)
for sid in sids:
    for r in ventral_raters:
        for roi in sub_contours:
            for hemi in ['lh', 'rh']:
                try:
                    dat = proc(contours_plan='ventral', rater=r, sid=sid, hemisphere=hemi, save_path=proc_path,
                               load_path=data_path)
                    x_coord, y_coord = dat['fsaverage_traces'][roi].points
                    x_coord = x_coord[sample_idx]
                    y_coord = y_coord[sample_idx]
                    data.append([x_coord, y_coord, sid, hemi, roi, r])
                except Exception as e:
                    print(e)

# save the data in a dataframe
df = pd.DataFrame(data, columns=['x_coord', 'y_coord', 'subject_id', 'hemi', 'contour', 'rater'])

# format the dataframe
df_fmt = df.explode(['x_coord','y_coord'])
df_fmt['rater'] = df_fmt['rater'].astype('category')
df_fmt['x_coord'] = df_fmt['x_coord'].astype('float')
df_fmt['y_coord'] = df_fmt['y_coord'].astype('float')
df_fmt['rater_code'] = df_fmt['rater'].cat.codes
df_fmt['loc_on_contour'] = df_fmt.groupby(level=0).cumcount()


# save the dataframe
df_fmt.to_csv('lmm_dataframes/df_LMM_average.csv')

df_fmt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 8>()
#      12 try:
#      13     dat = proc(contours_plan='ventral', rater=r, sid=sid, hemisphere=hemi, save_path=proc_path,
#      14                load_path=data_path)
# ---> 15     x_coord, y_coord = dat['fsaverage_traces'][roi].points
#      16     x_coord = x_coord[sample_idx]
#      17     y_coord = y_coord[sample_idx]
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:470, in IMap.__getitem__(self, k)
#     468 effval = self.efferents.get(k, self)
#     469 if effval is self:
# --> 470     self._run_node(self.plan.efferents[k])
#     471     return self.efferents[k]
#     472 else:
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:534, in IMap._run_node(self, node)
#     531     else: cpath = None
#     532     #except Exception: #(h, found) = (None, False)
#     533 # ensure we have a result
# --> 534 if not found: res = node(self)
#     535 # process the result:
#     536 effs = reduce(lambda m,v: m.set(v[0],v[1]), six.iteritems(res), self.efferents)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:91, in Calc.__call__(self, *args, **kwargs)
#      89         raise ValueError('required parameter %s not given to %s' % (name, self.name))
#      90     args.append(opts[name])
# ---> 91 result = self.function(*args)
#      92 if is_map(result):
#      93     if len(result) != len(self.efferents) or not all(e in result for e in self.efferents):
#
# File ~/hcp-annot-vc/src/hcpannot/proc/core.py:526, in forward_fsaverage_traces(nested_data)
#     509 @pimms.calc('fsaverage_traces')
#     510 def forward_fsaverage_traces(nested_data):
#     511     """Retrieve the `'fsaverage_traces'` data from the `nested_data` initial
#     512     processing.
#     513
#    (...)
#     524         contours after projection to the fsaverage.
#     525     """
# --> 526     return (nested_data['fsaverage_traces'],)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:470, in IMap.__getitem__(self, k)
#     468 effval = self.efferents.get(k, self)
#     469 if effval is self:
# --> 470     self._run_node(self.plan.efferents[k])
#     471     return self.efferents[k]
#     472 else:
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:534, in IMap._run_node(self, node)
#     531     else: cpath = None
#     532     #except Exception: #(h, found) = (None, False)
#     533 # ensure we have a result
# --> 534 if not found: res = node(self)
#     535 # process the result:
#     536 effs = reduce(lambda m,v: m.set(v[0],v[1]), six.iteritems(res), self.efferents)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:91, in Calc.__call__(self, *args, **kwargs)
#      89         raise ValueError('required parameter %s not given to %s' % (name, self.name))
#      90     args.append(opts[name])
# ---> 91 result = self.function(*args)
#      92 if is_map(result):
#      93     if len(result) != len(self.efferents) or not all(e in result for e in self.efferents):
#
# File ~/hcp-annot-vc/src/hcpannot/proc/core.py:526, in forward_fsaverage_traces(nested_data)
#     509 @pimms.calc('fsaverage_traces')
#     510 def forward_fsaverage_traces(nested_data):
#     511     """Retrieve the `'fsaverage_traces'` data from the `nested_data` initial
#     512     processing.
#     513
#    (...)
#     524         contours after projection to the fsaverage.
#     525     """
# --> 526     return (nested_data['fsaverage_traces'],)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:470, in IMap.__getitem__(self, k)
#     468 effval = self.efferents.get(k, self)
#     469 if effval is self:
# --> 470     self._run_node(self.plan.efferents[k])
#     471     return self.efferents[k]
#     472 else:
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:534, in IMap._run_node(self, node)
#     531     else: cpath = None
#     532     #except Exception: #(h, found) = (None, False)
#     533 # ensure we have a result
# --> 534 if not found: res = node(self)
#     535 # process the result:
#     536 effs = reduce(lambda m,v: m.set(v[0],v[1]), six.iteritems(res), self.efferents)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:91, in Calc.__call__(self, *args, **kwargs)
#      89         raise ValueError('required parameter %s not given to %s' % (name, self.name))
#      90     args.append(opts[name])
# ---> 91 result = self.function(*args)
#      92 if is_map(result):
#      93     if len(result) != len(self.efferents) or not all(e in result for e in self.efferents):
#
# File ~/hcp-annot-vc/src/hcpannot/proc/core.py:526, in forward_fsaverage_traces(nested_data)
#     509 @pimms.calc('fsaverage_traces')
#     510 def forward_fsaverage_traces(nested_data):
#     511     """Retrieve the `'fsaverage_traces'` data from the `nested_data` initial
#     512     processing.
#     513
#    (...)
#     524         contours after projection to the fsaverage.
#     525     """
# --> 526     return (nested_data['fsaverage_traces'],)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:470, in IMap.__getitem__(self, k)
#     468 effval = self.efferents.get(k, self)
#     469 if effval is self:
# --> 470     self._run_node(self.plan.efferents[k])
#     471     return self.efferents[k]
#     472 else:
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:534, in IMap._run_node(self, node)
#     531     else: cpath = None
#     532     #except Exception: #(h, found) = (None, False)
#     533 # ensure we have a result
# --> 534 if not found: res = node(self)
#     535 # process the result:
#     536 effs = reduce(lambda m,v: m.set(v[0],v[1]), six.iteritems(res), self.efferents)
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/pimms/calculation.py:91, in Calc.__call__(self, *args, **kwargs)
#      89         raise ValueError('required parameter %s not given to %s' % (name, self.name))
#      90     args.append(opts[name])
# ---> 91 result = self.function(*args)
#      92 if is_map(result):
#      93     if len(result) != len(self.efferents) or not all(e in result for e in self.efferents):
#
# File ~/hcp-annot-vc/src/hcpannot/proc/core.py:662, in calc_fsaverage_traces(rater, sid, chirality, save_path, nested_data, io_options, region, npoints)
#     659 if overwrite is not True:
#     660     # We try loading them and only calculate them if we aren't overwriting.
#     661     try:
# --> 662         fsa_traces = load_traces(
#     663             rater, sid, h, region,
#     664             load_path=traces_path)
#     665     except FileNotFoundError:
#     666         pass
#
# File ~/hcp-annot-vc/src/hcpannot/io.py:458, in load_traces(rater, sid, h, filenames, load_path, missing_okay)
#     408 def load_traces(rater, sid, h, filenames,
#     409                 load_path=None,
#     410                 missing_okay=False):
#     411     """Loads a set of traces for a subject and hemisphere from a save path.
#     412
#     413     `load_traces(rater, sid, h, filenames, load_path)` loads a set of contours
#    (...)
#     456         successfully loaded.
#     457     """
# --> 458     return _load_annotdata(
#     459         'traces', _load_trace,
#     460         rater, sid, h, filenames,
#     461         load_path=load_path,
#     462         missing_okay=missing_okay)
#
# File ~/hcp-annot-vc/src/hcpannot/io.py:144, in _load_annotdata(tag, loadfn, rater, sid, h, filenames, load_path, missing_okay, step)
#     142 if filepath.exists():
#     143     try:
# --> 144         annots[name] = loadfn(filepath)
#     145     except Exception as e:
#     146         raise RuntimeError(
#     147             f"load_{tag} [{rater}/{sid}/{h}] failed for {name}:"
#     148             f" ({type(e)}) {e}")
#
# File ~/hcp-annot-vc/src/hcpannot/io.py:326, in _load_trace(filepath, mesh)
#     324 def _load_trace(filepath, mesh=None):
#     325     "Loads a single trace from the given filepath."
# --> 326     trace = ny.load(os.fspath(filepath), 'json')
#     327     if not isinstance(trace, dict):
#     328         raise RuntimeError("file does not contain a json mapping")
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/neuropythy/io/core.py:91, in load(filename, format, **kwargs)
#      89         raise ValueError('Format \'%s\' not recognized by neuropythy' % format)
#      90     (f,_,_,_) = importers[format]
# ---> 91     obj = f(filename, **kwargs)
#      92 if isinstance(obj, ObjectWithMetaData): obj = obj.with_meta(source_filename=filename)
#      93 return obj
#
# File ~/.conda/envs/cnn/lib/python3.10/site-packages/neuropythy/io/core.py:275, in load_json(filename, to)
#     273 if pimms.is_str(filename):
#     274     try:
# --> 275         with gzip.open(filename, 'rt') as fl: dat = json.load(fl)
#     276     except Exception:
#     277         with open(filename, 'rt') as fl: dat = json.load(fl)
#
# File ~/.conda/envs/cnn/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/.conda/envs/cnn/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/.conda/envs/cnn/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/.conda/envs/cnn/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %% [markdown]
# ### Create Fsnative Dataframe

# %%
# sampling from fsnative data is similar to fsaverage data

data_native = []
sample_idx = np.arange(0, 500, 10)
missing = defaultdict(list)
for sid in sids:
    for r in ventral_raters:
        for roi in sub_contours:
            for hemi in ['lh', 'rh']:
                try:
#                     dat = proc(contours_plan='ventral', rater=r, sid=sid, hemisphere=hemi, save_path=proc_path,
#                                load_path=data_path)
#                     x_coord, y_coord = dat['fsnative_traces'][roi].points
#                     x_coord = x_coord[sample_idx]
#                     y_coord = y_coord[sample_idx]

                    path = os.path.join(proc_path, 'fsnative_aligned', f"cacherater_{r}_{sid}_lh_{roi}.mgz")
                    data = ny.load(path)
                    x_coord = data[0][sample_idx]
                    y_coord = data[1][sample_idx]
                    data_native.append([x_coord, y_coord, sid, hemi, roi, r])
                except Exception as e:
                    print(e)

            
# save the data in a dataframe
df_native = pd.DataFrame(data_native, columns=['x_coord', 'y_coord', 'subject_id', 'hemi', 'contour', 'rater'])

# format the dataframe
df_fnat = df_native.explode(['x_coord','y_coord'])
df_fnat['rater'] = df_fnat['rater'].astype('category')
df_fnat['x_coord'] = df_fnat['x_coord'].astype('float')
df_fnat['y_coord'] = df_fnat['y_coord'].astype('float')
df_fnat['rater_code'] = df_fnat['rater'].cat.codes
df_fnat['loc_on_contour'] = df_fnat.groupby(level=0).cumcount()

# save the dataframe
df_fnat.to_csv('lmm_dataframes/df_LMM_native_aligned.csv')

df_fnat
# Out:
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_hV4_outer.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_hV4_outer.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_hV4_VO1.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_hV4_VO1.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_VO1_VO2.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_VO1_VO2.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_VO_outer.mgz
# Could not interpret source path: /data/crcns2021/results/proc/fsnative_aligned/cacherater_R5_200210_lh_VO_outer.mgz
#         x_coord    y_coord  subject_id hemi    contour rater  rater_code  \
# 0    -14.240262   1.235579      100610   lh  hV4_outer    R1           0
# 0    -14.919656   0.190854      100610   lh  hV4_outer    R1           0
# 0    -15.599050  -0.853872      100610   lh  hV4_outer    R1           0
# 0    -16.278442  -1.898596      100610   lh  hV4_outer    R1           0
# 0    -16.784143  -3.019203      100610   lh  hV4_outer    R1           0
# ...         ...        ...         ...  ...        ...   ...         ...
# 7231  11.748857 -48.247494      995174   rh   VO_outer    R5           4
# 7231  10.726291 -47.443592      995174   rh   VO_outer    R5           4
# 7231   9.703724 -46.639694      995174   rh   VO_outer    R5           4
# 7231   8.681158 -45.835796      995174   rh   VO_outer    R5           4
# 7231   7.658591 -45.031895      995174   rh   VO_outer    R5           4
#
#       loc_on_contour
# 0                  0
# 0                  1
# 0                  2
# 0                  3
# 0                  4
# ...              ...
# 7231              45
# 7231              46
# 7231              47
# 7231              48
# 7231              49
#
# [361600 rows x 8 columns]

# %%
sid = sids[15]
hemi = 'lh'

# %%
fig, axes = plt.subplots(1, 2)


for roi in sub_contours:
    for i, ax in enumerate(axes):
        # plot mean fsaverage of the subject
        dat = proc(contours_plan='ventral', rater='mean', sid=sid, hemisphere=hemi, save_path=proc_path,
                                   load_path=data_path)
        x_coord, y_coord = dat['fsaverage_traces'][roi].points
        x_coord = x_coord[sample_idx]
        y_coord = y_coord[sample_idx]
        ax.plot(x_coord, y_coord, 'c-', alpha=1, label='mean fsaverage')
        
        for r in ventral_raters[:3]:
            if i == 0:
                dat = proc(contours_plan='ventral', rater=r, sid=sid, hemisphere=hemi, save_path=proc_path,
                                           load_path=data_path)
                x_coord, y_coord = dat['fsnative_traces'][roi].points
                x_coord = x_coord[sample_idx]
                y_coord = y_coord[sample_idx]
                ax.plot(x_coord, y_coord, 'k-', alpha=0.3, label='proc fsnative')

            elif i == 1:
                path = os.path.join(proc_path, 'fsnative_aligned', f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
                data = ny.load(path)
                x_coord = data[0][sample_idx]
                y_coord = data[1][sample_idx]
                ax.plot(x_coord, y_coord, 'k-', alpha=0.3, label='cache fsnative')
                
            # plot rater fsaverage:
            dat = proc(contours_plan='ventral', rater=r, sid=sid, hemisphere=hemi, save_path=proc_path,
                               load_path=data_path)
            x_coord, y_coord = dat['fsaverage_traces'][roi].points
            x_coord = x_coord[sample_idx]
            y_coord = y_coord[sample_idx]
            ax.plot(x_coord, y_coord, 'r--', alpha=0.3, label='rater fsaverage')

        


for ax in axes:
    handles, labels = ax.get_legend_handles_labels()
    unique = dict()
    for h, l in zip(handles, labels):
        if l not in unique:
            unique[l] = h
    ax.legend(unique.values(), unique.keys())

# %% [markdown]
# ### Running the Linear Mixed-Effect Model in R

# %% [markdown]
# ### Read the results into `pandas` dataframes and format

# %%
result_dir = 'lmm_results'
result_ave = pd.read_csv(os.path.join(result_dir, 'lm_result_average.csv'), index_col=0)

result_nat = pd.read_csv(os.path.join(result_dir, 'lm_result_native_aligned.csv'), index_col=0)

# %% [markdown]
# ### Clean results

# %%
# instead of changing the result, drop the invalid data points
result_ave = hcpannot.analysis.postprocess_result(result_ave, native_aligned=False)
result_nat = hcpannot.analysis.postprocess_result(result_nat, native_aligned=True)

# %%
result_ave
# Out:
#      varex_rater  varex_sbj hemi    contour  loc_on_contour  residual
# 0       0.029365   0.721202   lh    VO1_VO2               0  0.249432
# 1       0.027621   0.727945   lh    VO1_VO2               1  0.244434
# 2       0.026021   0.733891   lh    VO1_VO2               2  0.240087
# 3       0.024597   0.739206   lh    VO1_VO2               3  0.236197
# 4       0.023381   0.744067   lh    VO1_VO2               4  0.232553
# ..           ...        ...  ...        ...             ...       ...
# 395     0.132034   0.520408   rh  hV4_outer              45  0.347558
# 396     0.134028   0.511379   rh  hV4_outer              46  0.354593
# 397     0.135669   0.502572   rh  hV4_outer              47  0.361759
# 398     0.136933   0.493328   rh  hV4_outer              48  0.369739
# 399     0.138272   0.484309   rh  hV4_outer              49  0.377419
#
# [400 rows x 6 columns]

# %%
result_nat
# Out:
#      varex_rater  varex_sbj hemi    contour  loc_on_contour  residual
# 0       0.031974   0.720728   lh    VO1_VO2               0  0.247298
# 1       0.030237   0.726079   lh    VO1_VO2               1  0.243684
# 2       0.028641   0.730941   lh    VO1_VO2               2  0.240419
# 3       0.027220   0.735326   lh    VO1_VO2               3  0.237454
# 4       0.025963   0.739243   lh    VO1_VO2               4  0.234794
# ..           ...        ...  ...        ...             ...       ...
# 395     0.150874   0.480836   rh  hV4_outer              45  0.368290
# 396     0.152599   0.473812   rh  hV4_outer              46  0.373589
# 397     0.154448   0.466847   rh  hV4_outer              47  0.378705
# 398     0.156332   0.459573   rh  hV4_outer              48  0.384095
# 399     0.158180   0.452452   rh  hV4_outer              49  0.389368
#
# [400 rows x 6 columns]

# %%
result_nat[result_nat['contour'] == 'VO_outer']
# Out:
#      varex_rater  varex_sbj hemi   contour  loc_on_contour  residual
# 100     0.000210   0.991252   lh  VO_outer               0  0.008538
# 101     0.000816   0.988547   lh  VO_outer               1  0.010637
# 102     0.002444   0.980469   lh  VO_outer               2  0.017087
# 103     0.004959   0.967582   lh  VO_outer               3  0.027458
# 104     0.008230   0.950775   lh  VO_outer               4  0.040995
# ..           ...        ...  ...       ...             ...       ...
# 195     0.144201   0.456145   rh  VO_outer              45  0.399654
# 196     0.146349   0.454885   rh  VO_outer              46  0.398766
# 197     0.148942   0.453572   rh  VO_outer              47  0.397487
# 198     0.151970   0.452307   rh  VO_outer              48  0.395723
# 199     0.155814   0.450245   rh  VO_outer              49  0.393941
#
# [100 rows x 6 columns]

# %%
result_ave[result_ave['contour'] == 'hV4_outer']
# Out:
#      varex_rater  varex_sbj hemi    contour  loc_on_contour  residual
# 300     0.000000   1.000000   lh  hV4_outer               0  0.000000
# 301     0.000437   0.997802   lh  hV4_outer               1  0.001761
# 302     0.001747   0.991450   lh  hV4_outer               2  0.006802
# 303     0.003820   0.981413   lh  hV4_outer               3  0.014768
# 304     0.006502   0.968426   lh  hV4_outer               4  0.025072
# ..           ...        ...  ...        ...             ...       ...
# 395     0.132034   0.520408   rh  hV4_outer              45  0.347558
# 396     0.134028   0.511379   rh  hV4_outer              46  0.354593
# 397     0.135669   0.502572   rh  hV4_outer              47  0.361759
# 398     0.136933   0.493328   rh  hV4_outer              48  0.369739
# 399     0.138272   0.484309   rh  hV4_outer              49  0.377419
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Visulization

# %%
(fig, ax) = plt.subplots(len(sub_contours), 2, figsize=(6,8), dpi=600, sharey=True, sharex=True)
fig.tight_layout()

# fig.suptitle ('Variance Explained by Rater, Subject, and residual', y=1.05)
# fig.supxlabel('Location on Contour', y=-0.05)
# fig.supylabel('Variance Explained', x=-0.07)

colors = {
    'rater(avg)': '#1f77b4',
    'rater(nat)': '#aec7e8',
    'subject(avg)': '#2ca02c',
    'subject(nat)': '#98df8a',
    'residual(avg)': '#ff7f0e',
    'residual(nat)': '#ffbb78'
}

# plot the data for each contour
for i, contour in enumerate(sub_contours):
    
    # get the data for the contour
    ave_result = hcpannot.analysis.get_contour_data(result_ave, contour)
    nat_result = hcpannot.analysis.get_contour_data(result_nat, contour)
        
    # plot the data for each space
    for data, space in zip([ave_result, nat_result], ['avg', 'nat']):
        
        # plot the data for each hemisphere
        for j, hemi in enumerate(['lh', 'rh']):
            
            # get the data for the hemisphere
            hemi_data = data[hemi]
            
            # plot the rater
            label = f'rater({space})'
            ax[i,j].plot(hemi_data['rater'], label=label, c=colors[label])
            
            # plot the subject
            label = f'subject({space})'
            ax[i,j].plot(hemi_data['sbj'], label=label, c=colors[label])

            # plot the residual
            label = f'residual({space})'
            ax[i,j].plot(hemi_data['residual'], label=label, c=colors[label])


            # format the plot
            ax[i,j].set_title(f'{contour}, {hemi}')
            ax[i,j].set_xlim(-2, 51)
            ax[i,j].set_ylim(-0.05,1.1)
            ax[i,j].spines['top'].set_visible(False)
            ax[i,j].spines['right'].set_visible(False)
            ax[i,j].spines['left'].set_visible(False)
            ax[i,j].spines['bottom'].set_visible(False)
            ax[i,j].plot([-2,-2], [0,1], 'k-', lw=1.5)
            ax[i,j].plot([0,50], [-0.05, -0.05], 'k-', lw=1.5)
            
            # set the x-axis labels
            ticks = np.linspace(0, 49, num = 3)
            labels = [f'{num/49*100:.0f}%' for num in ticks]

            ax[i,j].set_xticks(ticks=ticks, labels=labels)
            ax[i,j].plot(0.985, -0.05, ">k", markersize=4, transform=ax[i,j].get_yaxis_transform(), clip_on=False)
            
h, l = ax[0,0].get_legend_handles_labels()
ax[0,0].legend(h, l, fontsize=10, bbox_to_anchor=(-0.25, 1))

# %%
# Same as above but removed subplot titles and adjusted spacing for making the figure for the paper

(fig, ax) = plt.subplots(len(sub_contours), 2, figsize=(3.25, 4.8), dpi=1200, sharey=True, sharex=True)

fig.supylabel('Fraction of Variance Explained', fontsize=10)
fig.supxlabel('% Distance Along Contour', x=0.55, y=0.03, fontsize=10)


colors = {
    'rater(avg)': '#1f77b4',
    'rater(nat)': '#aec7e8',
    'subject(avg)': '#2ca02c',
    'subject(nat)': '#98df8a',
    'residual(avg)': '#ff7f0e',
    'residual(nat)': '#ffbb78'
}

# plot the data for each contour
for i, contour in enumerate(sub_contours):
    
    # get the data for the contour
    ave_result = hcpannot.analysis.get_contour_data(result_ave, contour)
    nat_result = hcpannot.analysis.get_contour_data(result_nat, contour)
        
    # plot the data for each space
    for data, space in zip([ave_result, nat_result], ['avg', 'nat']):
        
        # plot the data for each hemisphere
        for j, hemi in enumerate(['lh', 'rh']):
            
            # get the data for the hemisphere
            hemi_data = data[hemi]
            
            # plot the rater
            label = f'rater({space})'
            ax[i,j].plot(hemi_data['rater'], label=label, c=colors[label])
            
            # plot the subject
            label = f'subject({space})'
            ax[i,j].plot(hemi_data['sbj'], label=label, c=colors[label])

            # plot the residual
            label = f'residual({space})'
            ax[i,j].plot(hemi_data['residual'], label=label, c=colors[label])

            # format the plot
            # ax[i,j].set_title(f'{contour}, {hemi}')
            ax[i,j].set_xlim(-2, 51)
            ax[i,j].set_ylim(-0.05,1.1)
            ax[i,j].spines['top'].set_visible(False)
            ax[i,j].spines['right'].set_visible(False)
            ax[i,j].spines['left'].set_visible(False)
            ax[i,j].spines['bottom'].set_visible(False)
            ax[i,j].plot([-2,-2], [0,1], 'k-', lw=1.5)
            ax[i,j].plot([0,50], [-0.05, -0.05], 'k-', lw=1.5)
            
            # set the x-axis labels
            ticks = np.linspace(0, 49, num = 3)
            labels = [f'{num/49*100:.0f}%' for num in ticks]

            ax[i,j].set_xticks(ticks=ticks, labels=labels, fontsize=10)
            ax[i,j].plot(0.985, -0.05, ">k", markersize=4, 
                         transform=ax[i,j].get_yaxis_transform(), clip_on=False)
            
fig.subplots_adjust(
    left=0.17,
    right=0.95,  
    bottom=0.12, 
    top=0.98,   
    hspace=0.3  
)            
            
fig.savefig('images/variance_line.pdf')

# %% [markdown]
# ## Visualizing ratio of variance explained by rater to subject

# %% [markdown]
# ### Calculate ratio of vriance explained by rater to subject

# %%
# calculate ratio of variance explained by researcher to that by subject
result_ave['r2s_variance'] = result_ave['varex_rater'] / result_ave['varex_sbj']
result_nat['r2s_variance'] = result_nat['varex_rater'] / result_nat['varex_sbj']

# %% [markdown]
# ### Visualization

# %%
(fig, ax) = plt.subplots(len(sub_contours), 2, figsize=(8,7), dpi= 72*8, sharey=True, sharex=True, 
                         layout="constrained")
plt.tight_layout()
fig.suptitle ('Variance Explained by Rater to Subject', y=1.05)
fig.supxlabel('Location on Contour', y=-0.025)
fig.supylabel('Ratio of Var Explained by Rater to Subject', x=0)

for i, contour in enumerate(sub_contours):
    
    data_lh = result_ave[(result_ave['hemi'] == 'lh') & (result_ave['contour'] == contour)]  
    data_rh = result_ave[(result_ave['hemi'] == 'rh') & (result_ave['contour'] == contour)]
        
    data_lh_nat = result_nat[(result_nat['hemi'] == 'lh') & (result_nat['contour'] == contour)]
    data_rh_nat = result_nat[(result_nat['hemi'] == 'rh') & (result_nat['contour'] == contour)]  
    
    ax[i,0].plot(np.arange(50), data_lh['r2s_variance'], label='fsaverage')
    ax[i,1].plot(np.arange(50), data_rh['r2s_variance'], label='fsaverage')
    
    ax[i,0].plot(np.arange(50), data_lh_nat['r2s_variance'], label='fsnative')
    ax[i,1].plot(np.arange(50), data_rh_nat['r2s_variance'], label='fsnative')
    
    ax[i,0].set_title(f'{contour}, lh')
    ax[i,1].set_title(f'{contour}, rh')
    
    for j in [0,1]:
        ax[i,j].spines['top'].set_visible(False)
        ax[i,j].spines['right'].set_visible(False)

h, l = ax[0,0].get_legend_handles_labels()
ax[0,0].legend(h, l, fontsize=12, bbox_to_anchor=(-0.15, 1))

#fig.savefig('images/rater2sbj_variance.png', bbox_inches='tight')
# Out:
# /tmp/ipykernel_6845/1893340133.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### Hemispheric asymmetry

# %%
# visualize the hemispheric assymetry of the variance explained by rater to subject

(fig, ax) = plt.subplots(len(sub_contours), 1, figsize=(5,5), dpi=72*8, sharey=True, sharex=True, 
                         layout="constrained")
plt.tight_layout()
fig.suptitle ('Discrepency of Variance Explained by Rater to Subject in LH vs. RH (RH-LH)', y=1.05)
fig.supxlabel('Location on Contour', y=-0.025)
fig.supylabel('Ratio of Var Explained by Rater to Subject', x=-0.05)

for i, contour in enumerate(sub_contours):
    
    avg_result = hcpannot.analysis.get_contour_data(result_ave, contour)
    nat_result = hcpannot.analysis.get_contour_data(result_nat, contour)
    
    ax[i].plot(np.arange(50), avg_result['rh']['r2s_variance'] - avg_result['lh']['r2s_variance'], label='fsaverage')
    ax[i].plot(np.arange(50), nat_result['rh']['r2s_variance'] - nat_result['lh']['r2s_variance'], label='fsnative')

    ax[i].set_title(contour)

h, l = ax[0].get_legend_handles_labels()
ax[0].legend(h, l, fontsize=12, bbox_to_anchor=(-0.1, 1))

#fig.savefig('images/rater2sbj_variance.pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_6845/3957242163.py:5: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### Plot line width plot of ratio of variance explained by rater to subject

# %%
(fig,ax) = plt.subplots(1, 1, figsize = (5,2.5), dpi = 72*8)
fig.suptitle('Ratio of Variance Explained by Rater to Subject (fsaverage)')

ax.axis('off')

for i, hemi in enumerate(['lh', 'rh']):    
    hmap = hcpannot.analysis.plot_lw(result_ave, hemi, sub_contours, flatmap=False, contour_save_path=contour_save_path, proc_path=proc_path, ax=ax)
    
cb = fig.colorbar(hmap)
cb.ax.tick_params(labelsize=8)
cb.set_label('ratio of researcher to subject variance', fontsize=8)

#plt.savefig('images/rater2sbj_variance_fsaverage.png')

# %%
(fig,ax) = plt.subplots(1, 1, figsize = (5,2.5), dpi = 72*8)
fig.suptitle('Ratio of Variance Explained by Rater to Subject (fsnative)')

ax.axis('off')

for i, hemi in enumerate(['lh', 'rh']):    
    hmap = hcpannot.analysis.plot_lw(result_nat, hemi, sub_contours, flatmap=False, contour_save_path=contour_save_path, proc_path=proc_path, ax=ax)
    
cb = fig.colorbar(hmap)
cb.ax.tick_params(labelsize=8)
cb.set_label('ratio of rater to subject variance', fontsize=8)

#plt.savefig('images/rater2sbj_variance_fsaverage.png')

# %% [markdown]
# ### Linewidth plot on flatmap

# %%
result_ave
# Out:
#      varex_rater  varex_sbj hemi    contour  loc_on_contour  residual  \
# 0       0.029365   0.721202   lh    VO1_VO2               0  0.249432
# 1       0.027621   0.727945   lh    VO1_VO2               1  0.244434
# 2       0.026021   0.733891   lh    VO1_VO2               2  0.240087
# 3       0.024597   0.739206   lh    VO1_VO2               3  0.236197
# 4       0.023381   0.744067   lh    VO1_VO2               4  0.232553
# ..           ...        ...  ...        ...             ...       ...
# 395     0.132034   0.520408   rh  hV4_outer              45  0.347558
# 396     0.134028   0.511379   rh  hV4_outer              46  0.354593
# 397     0.135669   0.502572   rh  hV4_outer              47  0.361759
# 398     0.136933   0.493328   rh  hV4_outer              48  0.369739
# 399     0.138272   0.484309   rh  hV4_outer              49  0.377419
#
#      r2s_variance
# 0        0.040717
# 1        0.037944
# 2        0.035456
# 3        0.033275
# 4        0.031423
# ..            ...
# 395      0.253712
# 396      0.262092
# 397      0.269950
# 398      0.277571
# 399      0.285505
#
# [400 rows x 7 columns]

# %%
(fig, ax) = plt.subplots(1, 2, figsize=(8,3), dpi=72*8)
fig.suptitle('Ratio of Variance Explained by Rater to Subject (fsaverage)')

for i, hemi in enumerate(['lh', 'rh']):

    ax[i].axis('equal')
    ax[i].axis('off')
    
    hmap = hcpannot.analysis.plot_lw(result_ave, hemi, sub_contours, flatmap=True, contour_save_path=contour_save_path, proc_path=proc_path, ax=ax[i])
    
# format the plot
cb = fig.colorbar(hmap)
# cb.ax.tick_params(labelsize=8)
cb.set_label('Ratio of Variance Explained by Researcher to Subject')

plt.savefig('images/rater2sbj_variance_fsaverage_cortex.pdf')

# %%
(fig, ax) = plt.subplots(1, 2, figsize=(8,3), dpi=72*8)
fig.suptitle('Ratio of Variance Explained by Rater to Subject (fsnative)')

for i, hemi in enumerate(['lh', 'rh']):

    ax[i].axis('equal')
    ax[i].axis('off')
    
    hmap = hcpannot.analysis.plot_lw(result_nat, hemi, sub_contours, flatmap=True, contour_save_path=contour_save_path, proc_path=proc_path, ax=ax[i])
    
# format the plot
cb = fig.colorbar(hmap, format='%.2f')
# cb.ax.tick_params(labelsize=8)
cb.set_label('Ratio of Variance Explained by Researcher to Subject')

# plt.savefig('images/rater2sbj_variance_fsnative_cortex.pdf')

# %%
plot_subjects = sids[9:10]

fig, ax = plt.subplots(dpi=72*8)

c1 = np.array([1.0, 0.0, 0.0])
c2 = np.array([0.0, 1.0, 1.0])

hemi = 'rh'

roi = 'VO_outer'

aligned = True

for sid in plot_subjects:
    for ii, r in enumerate(ventral_raters):
        
        for roi in ['VO_outer', 'hV4_outer']:
            
            if aligned == True:
                dir_name = 'fsnative_aligned'
            else:
                dir_name = 'fsnative'
        
            # read fsnative_aligned data
            fsnative_path = os.path.join(proc_path, dir_name, f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
            fsnative_data = ny.load(fsnative_path)
            x_coords = fsnative_data[0]
            y_coords = fsnative_data[1]
            
            ax.plot(x_coords, y_coords, '-', c=(1+ii)/len(ventral_raters)*c1)
            
            # read fsaverage data
            fsaverage_path = os.path.join(proc_path, 'fsaverage', f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
            fsaverage_data = ny.load(fsaverage_path)
            x_coords = fsaverage_data[0]
            y_coords = fsaverage_data[1]
            
            ax.plot(x_coords, y_coords, '-', c=(1+ii)/len(ventral_raters)*c2)
            
            # fsnative_path = os.path.join(proc_path, 'fsnative', f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
            # fsnative_data = ny.load(fsnative_path)
            # x_coords = fsnative_data[0]
            # y_coords = fsnative_data[1]
            
            # ax.plot(x_coords, y_coords, '-', c=(1+ii)/len(ventral_raters)*c1)

# %%
plot_subjects = sids[9:10]

fig, ax = plt.subplots(dpi=72*8)

c1 = np.array([1.0, 0.0, 0.0])
c2 = np.array([0.0, 1.0, 1.0])
c3 = np.array([0.0, 0.0, 1.0])

hemi = 'rh'

roi = 'VO_outer'

aligned = True

for sid in plot_subjects:
    for roi in ['VO_outer', 'hV4_outer']:
        for ii, r in enumerate(ventral_raters):
        
            # read fsnative_aligned data
            fsnative_path = os.path.join(proc_path, 'fsnative_aligned', f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
            fsnative_data = ny.load(fsnative_path)
            x_coords = fsnative_data[0]
            y_coords = fsnative_data[1]
            
            ax.plot(x_coords, y_coords, '-', c=(1+ii)/len(ventral_raters)*c1)
            
            fsnative_path = os.path.join(proc_path, 'fsnative', f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
            fsnative_data = ny.load(fsnative_path)
            x_coords = fsnative_data[0]
            y_coords = fsnative_data[1]
            
            ax.plot(x_coords, y_coords, '-', c=(1+ii)/len(ventral_raters)*c3)

        r = 'mean'
        
        # read fsaverage data
        fsaverage_path = os.path.join(proc_path, 'fsaverage', f"cacherater_{r}_{sid}_{hemi}_{roi}.mgz")
        fsaverage_data = ny.load(fsaverage_path)
        x_coords = fsaverage_data[0]
        y_coords = fsaverage_data[1]
        
        ax.plot(x_coords, y_coords, '-', c=c2)   
        
ax.set_title('aligned')
ax.set_xlim(-60, 40)
ax.set_ylim(-80, 20)
# Out:
# (-80.0, 20.0)
